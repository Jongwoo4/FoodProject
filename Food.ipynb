# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Downloads/archive/RAW_recipes.csv')
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']] = df.nutrition.str.split(",",expand=True) 
df['calories'] =  df['calories'].apply(lambda x: x.replace('[','')) 
df['carbohydrates (PDV)'] =  df['carbohydrates (PDV)'].apply(lambda x: x.replace(']','')) 
df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']] = \
df[['calories','total fat (PDV)','sugar (PDV)','sodium (PDV)','protein (PDV)','saturated fat (PDV)','carbohydrates (PDV)']].astype('float')

# %%
df.drop(['contributor_id','submitted','nutrition'], axis=1,inplace = True)

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 2  ['time-to-make', 'course', 'preparation', 'mai...        6
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 4  ['weeknight', 'time-to-make', 'course', 'main-...        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# ...

# %%
items = df['tags'][0].split(",")
items[0] = items[0][2:-1]
items[len(items)-1] = items[len(items)-1][2:-2]
for i in range(1,len(items)):
    items[i] = items[i][2:-1]
items[len(items)-1] = items[len(items)-1][:-1]   
print(items)
# Out:
# ['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'side-dishes', 'vegetables', 'mexican', 'easy', 'fall', 'holiday-event', 'vegetarian', 'winter', 'dietary', 'christmas', 'seasonal', 'ua']

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 2  ['time-to-make', 'course', 'preparation', 'mai...        6
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 4  ['weeknight', 'time-to-make', 'course', 'main-...        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# ...

# %%
for i in df['tags'].index:
    items = df['tags'][i].split(",")
    items[0] = items[0][2:-1]
    items[len(items)-1] = items[len(items)-1][2:-2]
    for i in range(1,len(items)):
        items[i] = items[i][2:-1]
    items[len(items)-1] = items[len(items)-1][:-1]
    for item in items:
        if(item not in list(df.columns)):
            df[item] = np.nan
            df[item][i] = 1
        else:
            df[item][i] = 1
# Out:
# <ipython-input-33-0698fadedda1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[item][i] = 1
# <ipython-input-33-0698fadedda1>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[item][i] = 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-0698fadedda1> in <module>
#      11             df[item][i] = 1
#      12         else:
# ---> 13             df[item][i] = 1
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     999
# ...

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 2  ['time-to-make', 'course', 'preparation', 'mai...        6
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 4  ['weeknight', 'time-to-make', 'course', 'main-...        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# ...
